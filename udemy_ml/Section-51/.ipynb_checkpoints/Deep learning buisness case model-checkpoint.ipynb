# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# # Data

# %%
npz = np.load('Audiobook_train_data.npz')

train_inputs, train_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

npz = np.load('Audiobook_validation_data.npz')

validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

npz = np.load('Audiobook_test_data.npz')

test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %% [markdown]
# # Model

# %%
input_size = 10
hidden_layer_size = 50
output_size = 2

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
    tf.keras.layers.Dense(output_size, activation = 'softmax')
])

model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

batch_size = 100
max_epoch = 100

early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2)

model.fit(train_inputs, 
          train_targets, 
          batch_size = batch_size, 
          epochs = max_epoch,
          callbacks = [early_stopping],
          validation_data = (validation_inputs, validation_targets),
          verbose = 2)
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 1s - loss: 0.5602 - accuracy: 0.7860 - val_loss: 0.4412 - val_accuracy: 0.8680
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.3780 - accuracy: 0.8723 - val_loss: 0.3365 - val_accuracy: 0.8814
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.3253 - accuracy: 0.8843 - val_loss: 0.3149 - val_accuracy: 0.8837
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.3045 - accuracy: 0.8882 - val_loss: 0.2988 - val_accuracy: 0.8904
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.2892 - accuracy: 0.8927 - val_loss: 0.2882 - val_accuracy: 0.8971
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.2772 - accuracy: 0.8975 - val_loss: 0.2838 - val_accuracy: 0.8971
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.2686 - accuracy: 0.9022 - val_loss: 0.2760 - val_accuracy: 0.9016
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.2615 - accuracy: 0.9033 - val_loss: 0.2693 - val_accuracy: 0.9016
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.2562 - accuracy: 0.9036 - val_loss: 0.2674 - val_accuracy: 0.9060
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.2535 - accuracy: 0.9056 - val_loss: 0.2664 - val_accuracy: 0.9038
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.2501 - accuracy: 0.9061 - val_loss: 0.2628 - val_accuracy: 0.9016
# Epoch 12/100
# 3579/3579 - 0s - loss: 0.2472 - accuracy: 0.9078 - val_loss: 0.2610 - val_accuracy: 0.9038
# Epoch 13/100
# 3579/3579 - 0s - loss: 0.2436 - accuracy: 0.9070 - val_loss: 0.2612 - val_accuracy: 0.9016
# Epoch 14/100
# 3579/3579 - 0s - loss: 0.2421 - accuracy: 0.9078 - val_loss: 0.2549 - val_accuracy: 0.9016
# Epoch 15/100
# 3579/3579 - 0s - loss: 0.2406 - accuracy: 0.9106 - val_loss: 0.2564 - val_accuracy: 0.9016
# Epoch 16/100
# 3579/3579 - 0s - loss: 0.2404 - accuracy: 0.9092 - val_loss: 0.2570 - val_accuracy: 0.9038

# %% [markdown]
# # Test the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 448/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
